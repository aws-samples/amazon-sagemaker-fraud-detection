# %% [markdown]
# # Fraud Detection with Amazon SageMaker FeatureStore
#
# Kernel `conda_python3` or `Python 3 (Data Science) - if using SageMaker Studio` works well with this notebook.
#
# The following policies need to be attached to the execution role:
# - AmazonSageMakerFullAccess
# - AmazonS3FullAccess
#
# ## Contents
# 1. [Background](#Background)
# 1. [Setup SageMaker FeatureStore](#Setup-SageMaker-FeatureStore)
# 1. [Inspect Dataset](#Inspect-Dataset)
# 1. [Ingest Data into FeatureStore](#Ingest-Data-into-FeatureStore)
# 1. [Build Training Dataset](#Build-Training-Dataset)
# 1. [Train and Deploy the Model](#Train-and-Deploy-the-Model)
# 1. [SageMaker FeatureStore At Inference](#SageMaker-FeatureStore-During-Inference)
# 1. [Cleanup Resources](#Cleanup-Resources)
#
# ## Background
#
# Amazon SageMaker FeatureStore is a SageMaker capability that makes it easy for customers to create and manage curated data for machine learning (ML) development. SageMaker FeatureStore enables data ingestion via a high TPS API and data consumption via the online and offline stores.
#
# This notebook provides an example for the APIs provided by SageMaker FeatureStore by walking through the process of training a fraud detection model. The notebook demonstrates how the dataset's tables can be ingested into the FeatureStore, queried to create a training dataset, and quickly accessed during inference.

# %% [markdown]
# ![FeatureStore-1.png](notebook_images/FeatureStore-1.png)

# %% [markdown]
# ![FeatureStore-2.png](notebook_images/FeatureStore-2.png)

# %% [markdown]
# ![FeatureStore-3.png](notebook_images/FeatureStore-3.png)

# %% [markdown]
# ![FeatureStore-4.png](notebook_images/FeatureStore-4.png)

# %% [markdown]
# ![FeatureStore-5.png](notebook_images/FeatureStore-5.png)

# %% [markdown]
# ### Terminology
#
# A **FeatureGroup** is the main resource that contains the metadata for all the data stored in SageMaker FeatureStore. A FeatureGroup contains a list of FeatureDefinitions. A **FeatureDefinition** consists of a name and one of the following data types: a integral, string or decimal. The FeatureGroup also contains an **OnlineStoreConfig** and an **OfflineStoreConfig** controlling where the data is stored. Enabling the online store allows quick access to the latest value for a Record via the GetRecord API. The offline store, a required configuration, allows storage of historical data in your S3 bucket.
#
# Once a FeatureGroup is created, data can be added as Records. **Records** can be thought of as a row in a table. Each record will have a unique **RecordIdentifier** along with values for all other FeatureDefinitions in the FeatureGroup.

# %% [markdown]
# ## Setup SageMaker FeatureStore IAM roles and S3 bucket access policies
# These are most likely set up for you by your platform infrastructure engineer/admin.
# - Please, add AmazonSageMakerFeatureStoreAccess IAM managed policy to your IAM role
# - Please, add an in-line policy that allows FeatureStore to access specific prefixes (i.e. "directories") in your S3 bucket.
#
# Note that you *can* use one IAM role for running this notebook and provide a different IAM role to CreateFeatureGroup API call.

# %% [markdown]
# #### See IAM role screenshots and IAM inline policy JSON below.

# %% [markdown]
# ![FeatureStore-5.png](notebook_images/FeatureStore_IAM_role_1.png)

# %% [markdown]
# ![FeatureStore-5.png](notebook_images/FeatureStore_IAM_role_2.png)

# %% [raw]
# # this is an example of IAM role __inline_policy__ statement that provides sufficient permissions to excersize FeatureStore capabilities in this notebook.
#
# {
#     "Version": "2012-10-17",
#     "Statement": [
#         {
#             "Sid": "VisualEditor0",
#             "Effect": "Allow",
#             "Action": [
#                 "s3:PutObject",
#                 "s3:GetObject",
#                 "s3:ListBucket",
#                 "s3:PutObjectAcl"
#             ],
#             "Resource": [
#                 "arn:aws:s3:::datalab-feature-store-bucket-se/home/sermolin/work/*",
#                 "arn:aws:s3:::datalab-feature-store-bucket-se/home/sermolin/featurestore/*"
#             ]
#         },
#         {
#             "Sid": "VisualEditor1",
#             "Effect": "Allow",
#             "Action": [
#                 "s3:ListAllMyBuckets",
#                 "s3:ListAccessPoints",
#                 "s3:ListJobs"
#             ],
#             "Resource": "*"
#         },
#         {
#             "Sid": "VisualEditor2",
#             "Effect": "Allow",
#             "Action": "s3:GetBucketAcl",
#             "Resource": "arn:aws:s3:::datalab-feature-store-bucket-se"
#         }
#     ]
# }

# %%
#run time measurement. Can be removed
from datetime import datetime, timedelta, timezone
import time
tic=time.time()

# %% [markdown]
# ## Setup SageMaker FeatureStore
#
# Let's start by setting up the SageMaker Python SDK and boto client. Note that this notebook requires a `boto3` version above `1.17.21`

# %%
import boto3
import sagemaker

original_boto3_version = boto3.__version__
# %pip install 'boto3>1.17.21'
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: boto3>1.17.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (1.24.60)
# Requirement already satisfied: botocore<1.28.0,>=1.27.60 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3>1.17.21) (1.27.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3>1.17.21) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3>1.17.21) (0.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from botocore<1.28.0,>=1.27.60->boto3>1.17.21) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from botocore<1.28.0,>=1.27.60->boto3>1.17.21) (1.26.8)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.60->boto3>1.17.21) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sagemaker.session import Session

region = boto3.Session().region_name

boto_session = boto3.Session(region_name=region)

sagemaker_client = boto_session.client(service_name="sagemaker", region_name=region)
featurestore_runtime = boto_session.client(
    service_name="sagemaker-featurestore-runtime", region_name=region
)

sagemaker_session_bucket= "datalab-feature-store-bucket-se"

feature_store_session = Session(
    boto_session=boto_session,
    sagemaker_client=sagemaker_client,
    sagemaker_featurestore_runtime_client=featurestore_runtime,
    default_bucket=sagemaker_session_bucket 
)
print(f"sagemaker bucket: {feature_store_session.default_bucket()}")
print(f"sagemaker session region: {feature_store_session.boto_region_name}")
# Out:
# sagemaker bucket: datalab-feature-store-bucket-se
# sagemaker session region: us-west-2

# %% [markdown]
# #### S3 Bucket Setup For The OfflineStore
#
# SageMaker FeatureStore writes the data in the OfflineStore of a FeatureGroup to a S3 bucket/prefix owned by you. Note that FeatureStore supports access to prefixes within the bucket, so that multiple users of FeatureStore could share the same S3 bucket. To be able to write to your S3 bucket/prefix, SageMaker FeatureStore assumes an IAM role which has access to it. The role is also owned by you.
# Note that the same bucket can be re-used across FeatureGroups. Data in the bucket is partitioned by FeatureGroup.

# %% [markdown]
# Set the default s3 bucket name and it will be referenced throughout the notebook.

# %%
# You can modify the following to use a bucket of your choosing
default_s3_bucket_name = feature_store_session.default_bucket() #currently, using the same bucket as for the sagemaker session, but it does not have to be
prefix = "home/sermolin/featurestore/sagemaker-featurestore-demo"

print(default_s3_bucket_name)
# Out:
# datalab-feature-store-bucket-se

# %%
from sagemaker import get_execution_role

# You can modify the following to use a role of your choosing. See the documentation for how to create this.
role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::328296961357:role/SageMakerFeatureStore

# %% [markdown]
# ## Inspect Dataset
#
# The provided dataset is a synthetic dataset with two tables: identity and transactions. They can both be joined by the `TransactionId` column. The transaction table contains information about a particular transaction such as amount, credit or debit card while the identity table contains information about the user such as device type and browser. The transaction must exist in the transaction table, but might not always be available in the identity table.
#
# The objective of the model is to predict if a transaction is fraudulent or not, given the transaction record.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io

s3_client = boto3.client("s3", region_name=region)

identity_data = pd.read_csv("data/sampled_identity.csv")
transaction_data = pd.read_csv("data/sampled_transactions.csv")

identity_data = identity_data.round(5)
transaction_data = transaction_data.round(5)

identity_data = identity_data.fillna(0)
transaction_data = transaction_data.fillna(0)

# Feature transformations for this dataset are applied before ingestion into FeatureStore.
# One hot encode card4, card6
encoded_card_bank = pd.get_dummies(transaction_data["card4"], prefix="card_bank")
encoded_card_type = pd.get_dummies(transaction_data["card6"], prefix="card_type")

transformed_transaction_data = pd.concat(
    [transaction_data, encoded_card_type, encoded_card_bank], axis=1
)
# blank space is not allowed in feature name
transformed_transaction_data = transformed_transaction_data.rename(
    columns={"card_bank_american express": "card_bank_american_express"}
)

# %%
identity_data.head()
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2990130     -5   38780.0    0.0    0.0    0.0    -70      0      1
# 1        2990266    -10   69246.0    0.0    0.0    0.0    -67      0      2
# 2        2992553    -45  348819.0    0.0    0.0    0.0    -73      0      0
# 3        2994568    -15  337170.0    0.0    0.0    0.0    -10      1      2
# 4        2994749     -5  680670.0    0.0    0.0    8.0     -1      2      2
#
#    id_09  ...  id_11  id_12  id_13  id_14  id_15  id_16  id_17 id_18 id_19  \
# 0  100.0  ...     32     80    253    241    260    125      T     F     F
# 1  100.0  ...     47     47    122     33     38     60      T     F     T
# 2  100.0  ...     21    143    268    111      2    135      F     F     T
# 3  100.0  ...     55    127    253    202    135     49      F     F     T
# 4  100.0  ...     52     43    257      7     19    254      F     F     T
#
#   id_20
# 0     T
# 1     F
# 2     F
# 3     T
# 4     T
#
# [5 rows x 21 columns]

# %%
transformed_transaction_data.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt  card1  card2  card3  \
# 0        3343087        0        8810855           29.00  12469  360.0  150.0
# 1        3307318        0        7955295          107.95  16188  178.0  150.0
# 2        3555327        0       15084339          159.95   1825  555.0  150.0
# 3        3310736        0        8017157          159.95  10057  225.0  150.0
# 4        3034711        0        1127470          117.00  11444  555.0  150.0
#
#         card4  card5  card6  ...  N8  N9  card_type_0  card_type_credit  \
# 0  mastercard  126.0  debit  ...   F   T            0                 0
# 1  mastercard  224.0  debit  ...   F   T            0                 0
# 2        visa  226.0  debit  ...   T   F            0                 0
# 3  mastercard  224.0  debit  ...   F   F            0                 0
# 4        visa  226.0  debit  ...   F   F            0                 0
#
#    card_type_debit  card_bank_0  card_bank_american_express  \
# 0                1            0                           0
# 1                1            0                           0
# 2                1            0                           0
# 3                1            0                           0
# 4                1            0                           0
#
#    card_bank_discover  card_bank_mastercard  card_bank_visa
# 0                   0                     1               0
# 1                   0                     1               0
# 2                   0                     0               1
# 3                   0                     1               0
# 4                   0                     0               1
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Ingest Data into FeatureStore

# %% [markdown]
# In this step we will create the FeatureGroups representing the transaction and identity tables.

# %% [markdown]
# #### Define FeatureGroups

# %%
from time import gmtime, strftime, sleep

identity_feature_group_name = "identity-feature-group-" + strftime("%d-%H-%M-%S", gmtime())
transaction_feature_group_name = "transaction-feature-group-" + strftime("%d-%H-%M-%S", gmtime())

# %%
from sagemaker.feature_store.feature_group import FeatureGroup

identity_feature_group = FeatureGroup(
    name=identity_feature_group_name, sagemaker_session=feature_store_session
)
transaction_feature_group = FeatureGroup(
    name=transaction_feature_group_name, sagemaker_session=feature_store_session
)

# %%
import time

current_time_sec = int(round(time.time()))


def cast_object_to_string(data_frame):
    for label in data_frame.columns:
        if data_frame.dtypes[label] == "object":
            data_frame[label] = data_frame[label].astype("str").astype("string")


# cast object dtype to string. The SageMaker FeatureStore Python SDK will then map the string dtype to String feature type.
cast_object_to_string(identity_data)
cast_object_to_string(transformed_transaction_data)

# record identifier and event time feature names
record_identifier_feature_name = "TransactionID"
event_time_feature_name = "EventTime"

# append EventTime feature
identity_data[event_time_feature_name] = pd.Series(
    [current_time_sec] * len(identity_data), dtype="float64"
)
transformed_transaction_data[event_time_feature_name] = pd.Series(
    [current_time_sec] * len(transaction_data), dtype="float64"
)

# load feature definitions to the feature group. SageMaker FeatureStore Python SDK will auto-detect the data schema based on input data.
identity_feature_group.load_feature_definitions(data_frame=identity_data)
# output is suppressed
transaction_feature_group.load_feature_definitions(data_frame=transformed_transaction_data)
# output is suppressed
# Out:
# [FeatureDefinition(feature_name='TransactionID', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='isFraud', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='TransactionDT', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='TransactionAmt', feature_type=<FeatureTypeEnum.FRACTIONAL: 'Fractional'>),
#  FeatureDefinition(feature_name='card1', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card2', feature_type=<FeatureTypeEnum.FRACTIONAL: 'Fractional'>),
#  FeatureDefinition(feature_name='card3', feature_type=<FeatureTypeEnum.FRACTIONAL: 'Fractional'>),
#  FeatureDefinition(feature_name='card4', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='card5', feature_type=<FeatureTypeEnum.FRACTIONAL: 'Fractional'>),
#  FeatureDefinition(feature_name='card6', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='B1', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B2', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B3', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B4', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B5', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B6', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B7', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B8', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B9', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B10', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B11', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='B12', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F1', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F2', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F3', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F4', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F5', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F6', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F7', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F8', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F9', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F10', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F11', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F12', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F13', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F14', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F15', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F16', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='F17', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='N1', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N2', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N3', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N4', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N5', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N6', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N7', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N8', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='N9', feature_type=<FeatureTypeEnum.STRING: 'String'>),
#  FeatureDefinition(feature_name='card_type_0', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_type_credit', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_type_debit', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_bank_0', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_bank_american_express', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_bank_discover', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_bank_mastercard', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='card_bank_visa', feature_type=<FeatureTypeEnum.INTEGRAL: 'Integral'>),
#  FeatureDefinition(feature_name='EventTime', feature_type=<FeatureTypeEnum.FRACTIONAL: 'Fractional'>)]

# %% [markdown]
# #### Create FeatureGroups in SageMaker FeatureStore

# %%
def wait_for_feature_group_creation_complete(feature_group):
    status = feature_group.describe().get("FeatureGroupStatus")
    while status == "Creating":
        print("Waiting for Feature Group Creation")
        time.sleep(5)
        status = feature_group.describe().get("FeatureGroupStatus")
    if status != "Created":
        raise RuntimeError(f"Failed to create feature group {feature_group.name}")
    print(f"FeatureGroup {feature_group.name} successfully created.")


identity_feature_group.create(
    s3_uri=f"s3://{default_s3_bucket_name}/{prefix}",
    record_identifier_name=record_identifier_feature_name,
    event_time_feature_name=event_time_feature_name,
    role_arn=role, ## note - this could be a *different* role from the one obtained above by calling role = get_execution_role().
                   ## this role could be scoped to a different S3 bucket/prefix and have different permissions.  
    enable_online_store=True,
)

transaction_feature_group.create(
    s3_uri=f"s3://{default_s3_bucket_name}/{prefix}",
    record_identifier_name=record_identifier_feature_name,
    event_time_feature_name=event_time_feature_name,
    role_arn=role,
    enable_online_store=True,
)

wait_for_feature_group_creation_complete(feature_group=identity_feature_group)
wait_for_feature_group_creation_complete(feature_group=transaction_feature_group)
# Out:
# Waiting for Feature Group Creation
# Waiting for Feature Group Creation
# FeatureGroup identity-feature-group-01-19-37-17 successfully created.
# Waiting for Feature Group Creation
# Waiting for Feature Group Creation
# FeatureGroup transaction-feature-group-01-19-37-17 successfully created.

# %%
#run time measurement. Can be removed
toc=time.time()
elapsed_time = toc-tic
print(elapsed_time)
str(timedelta(seconds=elapsed_time))
# Out:
# 30.123196125030518
# '0:00:30.123196'

# %% [markdown]
# Confirm the FeatureGroup has been created by using the DescribeFeatureGroup and ListFeatureGroups APIs.

# %%
identity_feature_group.describe()
# Out:
# {'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-01-19-37-17',
#  'FeatureGroupName': 'identity-feature-group-01-19-37-17',
#  'RecordIdentifierFeatureName': 'TransactionID',
#  'EventTimeFeatureName': 'EventTime',
#  'FeatureDefinitions': [{'FeatureName': 'TransactionID',
#    'FeatureType': 'Integral'},
#   {'FeatureName': 'id_01', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_02', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'id_03', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'id_04', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'id_05', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'id_06', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_07', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_08', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_09', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'id_10', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_11', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_12', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_13', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_14', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_15', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_16', 'FeatureType': 'Integral'},
#   {'FeatureName': 'id_17', 'FeatureType': 'String'},
#   {'FeatureName': 'id_18', 'FeatureType': 'String'},
#   {'FeatureName': 'id_19', 'FeatureType': 'String'},
#   {'FeatureName': 'id_20', 'FeatureType': 'String'},
#   {'FeatureName': 'EventTime', 'FeatureType': 'Fractional'}],
#  'CreationTime': datetime.datetime(2022, 9, 1, 19, 37, 17, 721000, tzinfo=tzlocal()),
#  'OnlineStoreConfig': {'EnableOnlineStore': True},
#  'OfflineStoreConfig': {'S3StorageConfig': {'S3Uri': 's3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo',
#    'ResolvedOutputS3Uri': 's3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo/328296961357/sagemaker/us-west-2/offline-store/identity-feature-group-01-19-37-17-1662061037/data'},
#   'DisableGlueTableCreation': False,
#   'DataCatalogConfig': {'TableName': 'identity-feature-group-01-19-37-17-1662061037',
#    'Catalog': 'AwsDataCatalog',
#    'Database': 'sagemaker_featurestore'}},
#  'RoleArn': 'arn:aws:iam::328296961357:role/SageMakerFeatureStore',
#  'FeatureGroupStatus': 'Created',
#  'OnlineStoreTotalSizeBytes': 0,
#  'ResponseMetadata': {'RequestId': '4c10b029-9796-4931-b77f-16973c2605b4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4c10b029-9796-4931-b77f-16973c2605b4',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '2201',
#    'date': 'Thu, 01 Sep 2022 19:37:43 GMT'},
#   'RetryAttempts': 0}}

# %%
transaction_feature_group.describe()
# Out:
# {'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-01-19-37-17',
#  'FeatureGroupName': 'transaction-feature-group-01-19-37-17',
#  'RecordIdentifierFeatureName': 'TransactionID',
#  'EventTimeFeatureName': 'EventTime',
#  'FeatureDefinitions': [{'FeatureName': 'TransactionID',
#    'FeatureType': 'Integral'},
#   {'FeatureName': 'isFraud', 'FeatureType': 'Integral'},
#   {'FeatureName': 'TransactionDT', 'FeatureType': 'Integral'},
#   {'FeatureName': 'TransactionAmt', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'card1', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card2', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'card3', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'card4', 'FeatureType': 'String'},
#   {'FeatureName': 'card5', 'FeatureType': 'Fractional'},
#   {'FeatureName': 'card6', 'FeatureType': 'String'},
#   {'FeatureName': 'B1', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B2', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B3', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B4', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B5', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B6', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B7', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B8', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B9', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B10', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B11', 'FeatureType': 'Integral'},
#   {'FeatureName': 'B12', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F1', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F2', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F3', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F4', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F5', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F6', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F7', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F8', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F9', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F10', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F11', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F12', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F13', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F14', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F15', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F16', 'FeatureType': 'Integral'},
#   {'FeatureName': 'F17', 'FeatureType': 'Integral'},
#   {'FeatureName': 'N1', 'FeatureType': 'String'},
#   {'FeatureName': 'N2', 'FeatureType': 'String'},
#   {'FeatureName': 'N3', 'FeatureType': 'String'},
#   {'FeatureName': 'N4', 'FeatureType': 'String'},
#   {'FeatureName': 'N5', 'FeatureType': 'String'},
#   {'FeatureName': 'N6', 'FeatureType': 'String'},
#   {'FeatureName': 'N7', 'FeatureType': 'String'},
#   {'FeatureName': 'N8', 'FeatureType': 'String'},
#   {'FeatureName': 'N9', 'FeatureType': 'String'},
#   {'FeatureName': 'card_type_0', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_type_credit', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_type_debit', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_bank_0', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_bank_american_express', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_bank_discover', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_bank_mastercard', 'FeatureType': 'Integral'},
#   {'FeatureName': 'card_bank_visa', 'FeatureType': 'Integral'},
#   {'FeatureName': 'EventTime', 'FeatureType': 'Fractional'}],
#  'CreationTime': datetime.datetime(2022, 9, 1, 19, 37, 22, 753000, tzinfo=tzlocal()),
#  'OnlineStoreConfig': {'EnableOnlineStore': True},
#  'OfflineStoreConfig': {'S3StorageConfig': {'S3Uri': 's3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo',
#    'ResolvedOutputS3Uri': 's3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo/328296961357/sagemaker/us-west-2/offline-store/transaction-feature-group-01-19-37-17-1662061042/data'},
#   'DisableGlueTableCreation': False,
#   'DataCatalogConfig': {'TableName': 'transaction-feature-group-01-19-37-17-1662061042',
#    'Catalog': 'AwsDataCatalog',
#    'Database': 'sagemaker_featurestore'}},
#  'RoleArn': 'arn:aws:iam::328296961357:role/SageMakerFeatureStore',
#  'FeatureGroupStatus': 'Created',
#  'OnlineStoreTotalSizeBytes': 0,
#  'ResponseMetadata': {'RequestId': '8d4091b5-5556-4061-be7d-1ec9248777ba',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8d4091b5-5556-4061-be7d-1ec9248777ba',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '3919',
#    'date': 'Thu, 01 Sep 2022 19:37:43 GMT'},
#   'RetryAttempts': 0}}

# %%
sagemaker_client.list_feature_groups()  # use boto client to list FeatureGroups
# Out:
# {'FeatureGroupSummaries': [{'FeatureGroupName': 'transaction-feature-group-22-23-10-10',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-22-23-10-10',
#    'CreationTime': datetime.datetime(2022, 2, 22, 23, 10, 12, 287000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'transaction-feature-group-22-22-36-55',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-22-22-36-55',
#    'CreationTime': datetime.datetime(2022, 2, 22, 22, 36, 56, 931000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'transaction-feature-group-22-22-06-54',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-22-22-06-54',
#    'CreationTime': datetime.datetime(2022, 2, 22, 22, 6, 56, 629000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'transaction-feature-group-01-19-37-17',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-01-19-37-17',
#    'CreationTime': datetime.datetime(2022, 9, 1, 19, 37, 22, 753000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created'},
#   {'FeatureGroupName': 'transaction-feature-group-01-19-08-37',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/transaction-feature-group-01-19-08-37',
#    'CreationTime': datetime.datetime(2022, 9, 1, 19, 8, 40, 482000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'identity-feature-group-22-23-10-10',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-22-23-10-10',
#    'CreationTime': datetime.datetime(2022, 2, 22, 23, 10, 10, 838000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'identity-feature-group-22-22-36-55',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-22-22-36-55',
#    'CreationTime': datetime.datetime(2022, 2, 22, 22, 36, 55, 863000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'identity-feature-group-22-22-06-54',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-22-22-06-54',
#    'CreationTime': datetime.datetime(2022, 2, 22, 22, 6, 54, 745000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}},
#   {'FeatureGroupName': 'identity-feature-group-01-19-37-17',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-01-19-37-17',
#    'CreationTime': datetime.datetime(2022, 9, 1, 19, 37, 17, 721000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created'},
#   {'FeatureGroupName': 'identity-feature-group-01-19-08-37',
#    'FeatureGroupArn': 'arn:aws:sagemaker:us-west-2:328296961357:feature-group/identity-feature-group-01-19-08-37',
#    'CreationTime': datetime.datetime(2022, 9, 1, 19, 8, 38, 253000, tzinfo=tzlocal()),
#    'FeatureGroupStatus': 'Created',
#    'OfflineStoreStatus': {'Status': 'Active'}}],
#  'NextToken': '...',
#  'ResponseMetadata': {'RequestId': '8724cf15-e570-4ead-83ca-dcdec78182bd',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8724cf15-e570-4ead-83ca-dcdec78182bd',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '3290',
#    'date': 'Thu, 01 Sep 2022 19:37:43 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### PutRecords into FeatureGroup
#
# After the FeatureGroups have been created, we can put data into the FeatureGroups by using the PutRecord API. This API can handle high TPS and is designed to be called by different streams. The data from all of these Put requests is buffered and written to S3 in chunks. The files will be written to the offline store within a few minutes of ingestion. For this example, to accelerate the ingestion process, we are specifying multiple workers to do the job simultaneously. It will take ~1min to ingest data to the 2 FeatureGroups, respectively.

# %%
identity_feature_group.ingest(data_frame=identity_data, max_workers=3, wait=True)
# Out:
# IngestionManagerPandas(feature_group_name='identity-feature-group-01-19-37-17', sagemaker_fs_runtime_client_config=<botocore.config.Config object at 0x7f84231e97c0>, max_workers=3, max_processes=1, profile_name=None, _async_result=<multiprocess.pool.MapResult object at 0x7f8420f524f0>, _processing_pool=<pool ProcessPool(ncpus=1)>, _failed_indices=[])

# %%
transaction_feature_group.ingest(data_frame=transformed_transaction_data, max_workers=5, wait=True)
# Out:
# IngestionManagerPandas(feature_group_name='transaction-feature-group-01-19-37-17', sagemaker_fs_runtime_client_config=<botocore.config.Config object at 0x7f84231e97c0>, max_workers=5, max_processes=1, profile_name=None, _async_result=<multiprocess.pool.MapResult object at 0x7f8420ee33a0>, _processing_pool=<pool ProcessPool(ncpus=1)>, _failed_indices=[])

# %% [markdown]
# To confirm that data has been ingested, we can quickly retrieve a record from the online store:

# %%
record_identifier_value = str(2990130)

featurestore_runtime.get_record(
    FeatureGroupName=transaction_feature_group_name,
    RecordIdentifierValueAsString=record_identifier_value,
)
# Out:
# {'ResponseMetadata': {'RequestId': 'b6b3c274-12df-4a6b-a283-a5350549b0dc',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'b6b3c274-12df-4a6b-a283-a5350549b0dc',
#    'content-type': 'application/json',
#    'content-length': '2636',
#    'date': 'Thu, 01 Sep 2022 19:37:51 GMT'},
#   'RetryAttempts': 0},
#  'Record': [{'FeatureName': 'TransactionID', 'ValueAsString': '2990130'},
#   {'FeatureName': 'isFraud', 'ValueAsString': '0'},
#   {'FeatureName': 'TransactionDT', 'ValueAsString': '152647'},
#   {'FeatureName': 'TransactionAmt', 'ValueAsString': '75.0'},
#   {'FeatureName': 'card1', 'ValueAsString': '4577'},
#   {'FeatureName': 'card2', 'ValueAsString': '583.0'},
#   {'FeatureName': 'card3', 'ValueAsString': '150.0'},
#   {'FeatureName': 'card4', 'ValueAsString': 'mastercard'},
#   {'FeatureName': 'card5', 'ValueAsString': '219.0'},
#   {'FeatureName': 'card6', 'ValueAsString': 'credit'},
#   {'FeatureName': 'B1', 'ValueAsString': '69'},
#   {'FeatureName': 'B2', 'ValueAsString': '80'},
#   {'FeatureName': 'B3', 'ValueAsString': '91'},
#   {'FeatureName': 'B4', 'ValueAsString': '77'},
#   {'FeatureName': 'B5', 'ValueAsString': '9'},
#   {'FeatureName': 'B6', 'ValueAsString': '53'},
#   {'FeatureName': 'B7', 'ValueAsString': '25'},
#   {'FeatureName': 'B8', 'ValueAsString': '16'},
#   {'FeatureName': 'B9', 'ValueAsString': '99'},
#   {'FeatureName': 'B10', 'ValueAsString': '1'},
#   {'FeatureName': 'B11', 'ValueAsString': '7'},
#   {'FeatureName': 'B12', 'ValueAsString': '63'},
#   {'FeatureName': 'F1', 'ValueAsString': '761'},
#   {'FeatureName': 'F2', 'ValueAsString': '679'},
#   {'FeatureName': 'F3', 'ValueAsString': '627'},
#   {'FeatureName': 'F4', 'ValueAsString': '943'},
#   {'FeatureName': 'F5', 'ValueAsString': '772'},
#   {'FeatureName': 'F6', 'ValueAsString': '911'},
#   {'FeatureName': 'F7', 'ValueAsString': '560'},
#   {'FeatureName': 'F8', 'ValueAsString': '563'},
#   {'FeatureName': 'F9', 'ValueAsString': '544'},
#   {'FeatureName': 'F10', 'ValueAsString': '715'},
#   {'FeatureName': 'F11', 'ValueAsString': '967'},
#   {'FeatureName': 'F12', 'ValueAsString': '715'},
#   {'FeatureName': 'F13', 'ValueAsString': '787'},
#   {'FeatureName': 'F14', 'ValueAsString': '871'},
#   {'FeatureName': 'F15', 'ValueAsString': '513'},
#   {'FeatureName': 'F16', 'ValueAsString': '719'},
#   {'FeatureName': 'F17', 'ValueAsString': '626'},
#   {'FeatureName': 'N1', 'ValueAsString': 'F'},
#   {'FeatureName': 'N2', 'ValueAsString': 'F'},
#   {'FeatureName': 'N3', 'ValueAsString': 'F'},
#   {'FeatureName': 'N4', 'ValueAsString': 'T'},
#   {'FeatureName': 'N5', 'ValueAsString': 'T'},
#   {'FeatureName': 'N6', 'ValueAsString': 'T'},
#   {'FeatureName': 'N7', 'ValueAsString': 'T'},
#   {'FeatureName': 'N8', 'ValueAsString': 'F'},
#   {'FeatureName': 'N9', 'ValueAsString': 'F'},
#   {'FeatureName': 'card_type_0', 'ValueAsString': '0'},
#   {'FeatureName': 'card_type_credit', 'ValueAsString': '1'},
#   {'FeatureName': 'card_type_debit', 'ValueAsString': '0'},
#   {'FeatureName': 'card_bank_0', 'ValueAsString': '0'},
#   {'FeatureName': 'card_bank_american_express', 'ValueAsString': '0'},
#   {'FeatureName': 'card_bank_discover', 'ValueAsString': '0'},
#   {'FeatureName': 'card_bank_mastercard', 'ValueAsString': '1'},
#   {'FeatureName': 'card_bank_visa', 'ValueAsString': '0'},
#   {'FeatureName': 'EventTime', 'ValueAsString': '1662061038.0'}]}

# %% [markdown]
# We can also retrieve a record of each feature group from the online store:

# %%
featurestore_runtime.batch_get_record(
    Identifiers=[
        {
            "FeatureGroupName": identity_feature_group_name,
            "RecordIdentifiersValueAsString": ["2990130"],
        },
        {
            "FeatureGroupName": transaction_feature_group_name,
            "RecordIdentifiersValueAsString": ["2990130"],
        },
    ]
)
# Out:
# {'ResponseMetadata': {'RequestId': '5f6d5945-6c68-4ee2-9d7f-58347e480cae',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '5f6d5945-6c68-4ee2-9d7f-58347e480cae',
#    'content-type': 'application/json',
#    'content-length': '3929',
#    'date': 'Thu, 01 Sep 2022 19:37:51 GMT'},
#   'RetryAttempts': 0},
#  'Records': [{'FeatureGroupName': 'identity-feature-group-01-19-37-17',
#    'RecordIdentifierValueAsString': '2990130',
#    'Record': [{'FeatureName': 'TransactionID', 'ValueAsString': '2990130'},
#     {'FeatureName': 'id_01', 'ValueAsString': '-5'},
#     {'FeatureName': 'id_02', 'ValueAsString': '38780.0'},
#     {'FeatureName': 'id_03', 'ValueAsString': '0.0'},
#     {'FeatureName': 'id_04', 'ValueAsString': '0.0'},
#     {'FeatureName': 'id_05', 'ValueAsString': '0.0'},
#     {'FeatureName': 'id_06', 'ValueAsString': '-70'},
#     {'FeatureName': 'id_07', 'ValueAsString': '0'},
#     {'FeatureName': 'id_08', 'ValueAsString': '1'},
#     {'FeatureName': 'id_09', 'ValueAsString': '100.0'},
#     {'FeatureName': 'id_10', 'ValueAsString': '36'},
#     {'FeatureName': 'id_11', 'ValueAsString': '32'},
#     {'FeatureName': 'id_12', 'ValueAsString': '80'},
#     {'FeatureName': 'id_13', 'ValueAsString': '253'},
#     {'FeatureName': 'id_14', 'ValueAsString': '241'},
#     {'FeatureName': 'id_15', 'ValueAsString': '260'},
#     {'FeatureName': 'id_16', 'ValueAsString': '125'},
#     {'FeatureName': 'id_17', 'ValueAsString': 'T'},
#     {'FeatureName': 'id_18', 'ValueAsString': 'F'},
#     {'FeatureName': 'id_19', 'ValueAsString': 'F'},
#     {'FeatureName': 'id_20', 'ValueAsString': 'T'},
#     {'FeatureName': 'EventTime', 'ValueAsString': '1662061038.0'}]},
#   {'FeatureGroupName': 'transaction-feature-group-01-19-37-17',
#    'RecordIdentifierValueAsString': '2990130',
#    'Record': [{'FeatureName': 'TransactionID', 'ValueAsString': '2990130'},
#     {'FeatureName': 'isFraud', 'ValueAsString': '0'},
#     {'FeatureName': 'TransactionDT', 'ValueAsString': '152647'},
#     {'FeatureName': 'TransactionAmt', 'ValueAsString': '75.0'},
#     {'FeatureName': 'card1', 'ValueAsString': '4577'},
#     {'FeatureName': 'card2', 'ValueAsString': '583.0'},
#     {'FeatureName': 'card3', 'ValueAsString': '150.0'},
#     {'FeatureName': 'card4', 'ValueAsString': 'mastercard'},
#     {'FeatureName': 'card5', 'ValueAsString': '219.0'},
#     {'FeatureName': 'card6', 'ValueAsString': 'credit'},
#     {'FeatureName': 'B1', 'ValueAsString': '69'},
#     {'FeatureName': 'B2', 'ValueAsString': '80'},
#     {'FeatureName': 'B3', 'ValueAsString': '91'},
#     {'FeatureName': 'B4', 'ValueAsString': '77'},
#     {'FeatureName': 'B5', 'ValueAsString': '9'},
#     {'FeatureName': 'B6', 'ValueAsString': '53'},
#     {'FeatureName': 'B7', 'ValueAsString': '25'},
#     {'FeatureName': 'B8', 'ValueAsString': '16'},
#     {'FeatureName': 'B9', 'ValueAsString': '99'},
#     {'FeatureName': 'B10', 'ValueAsString': '1'},
#     {'FeatureName': 'B11', 'ValueAsString': '7'},
#     {'FeatureName': 'B12', 'ValueAsString': '63'},
#     {'FeatureName': 'F1', 'ValueAsString': '761'},
#     {'FeatureName': 'F2', 'ValueAsString': '679'},
#     {'FeatureName': 'F3', 'ValueAsString': '627'},
#     {'FeatureName': 'F4', 'ValueAsString': '943'},
#     {'FeatureName': 'F5', 'ValueAsString': '772'},
#     {'FeatureName': 'F6', 'ValueAsString': '911'},
#     {'FeatureName': 'F7', 'ValueAsString': '560'},
#     {'FeatureName': 'F8', 'ValueAsString': '563'},
#     {'FeatureName': 'F9', 'ValueAsString': '544'},
#     {'FeatureName': 'F10', 'ValueAsString': '715'},
#     {'FeatureName': 'F11', 'ValueAsString': '967'},
#     {'FeatureName': 'F12', 'ValueAsString': '715'},
#     {'FeatureName': 'F13', 'ValueAsString': '787'},
#     {'FeatureName': 'F14', 'ValueAsString': '871'},
#     {'FeatureName': 'F15', 'ValueAsString': '513'},
#     {'FeatureName': 'F16', 'ValueAsString': '719'},
#     {'FeatureName': 'F17', 'ValueAsString': '626'},
#     {'FeatureName': 'N1', 'ValueAsString': 'F'},
#     {'FeatureName': 'N2', 'ValueAsString': 'F'},
#     {'FeatureName': 'N3', 'ValueAsString': 'F'},
#     {'FeatureName': 'N4', 'ValueAsString': 'T'},
#     {'FeatureName': 'N5', 'ValueAsString': 'T'},
#     {'FeatureName': 'N6', 'ValueAsString': 'T'},
#     {'FeatureName': 'N7', 'ValueAsString': 'T'},
#     {'FeatureName': 'N8', 'ValueAsString': 'F'},
#     {'FeatureName': 'N9', 'ValueAsString': 'F'},
#     {'FeatureName': 'card_type_0', 'ValueAsString': '0'},
#     {'FeatureName': 'card_type_credit', 'ValueAsString': '1'},
#     {'FeatureName': 'card_type_debit', 'ValueAsString': '0'},
#     {'FeatureName': 'card_bank_0', 'ValueAsString': '0'},
#     {'FeatureName': 'card_bank_american_express', 'ValueAsString': '0'},
#     {'FeatureName': 'card_bank_discover', 'ValueAsString': '0'},
#     {'FeatureName': 'card_bank_mastercard', 'ValueAsString': '1'},
#     {'FeatureName': 'card_bank_visa', 'ValueAsString': '0'},
#     {'FeatureName': 'EventTime', 'ValueAsString': '1662061038.0'}]}],
#  'Errors': [],
#  'UnprocessedIdentifiers': []}

# %% [markdown]
# The SageMaker Python SDK’s FeatureStore class also provides the functionality to generate Hive DDL commands. Schema of the table is generated based on the feature definitions. Columns are named after feature name and data-type are inferred based on feature type.

# %%
#suppressing print output of HIVE DLL format
#print(identity_feature_group.as_hive_ddl())

# %%
#suppressing print output of HIVE DLL format
#print(transaction_feature_group.as_hive_ddl())

# %% [markdown]
# Now let's wait for the data to appear in our offline store before moving forward to creating a dataset. This will take approximately 5 minutes.

# %%
# %%time
account_id = boto3.client("sts").get_caller_identity()["Account"]
print(account_id)

identity_feature_group_resolved_output_s3_uri = (
    identity_feature_group.describe()
    .get("OfflineStoreConfig")
    .get("S3StorageConfig")
    .get("ResolvedOutputS3Uri")
)
transaction_feature_group_resolved_output_s3_uri = (
    transaction_feature_group.describe()
    .get("OfflineStoreConfig")
    .get("S3StorageConfig")
    .get("ResolvedOutputS3Uri")
)

identity_feature_group_s3_prefix = identity_feature_group_resolved_output_s3_uri.replace(
    f"s3://{default_s3_bucket_name}/", ""
)
transaction_feature_group_s3_prefix = transaction_feature_group_resolved_output_s3_uri.replace(
    f"s3://{default_s3_bucket_name}/", ""
)

offline_store_contents = None
while offline_store_contents is None:
    objects_in_bucket = s3_client.list_objects(
        Bucket=default_s3_bucket_name, Prefix=transaction_feature_group_s3_prefix
    )
    if "Contents" in objects_in_bucket and len(objects_in_bucket["Contents"]) > 1:
        offline_store_contents = objects_in_bucket["Contents"]
    else:
        print("Waiting for data in offline store...\n")
        sleep(60)

print("Data available.")
# Out:
# 328296961357
# Waiting for data in offline store...
#
# Waiting for data in offline store...
#
# Waiting for data in offline store...
#
# Waiting for data in offline store...
#
# Waiting for data in offline store...
#
# Waiting for data in offline store...
#
# Data available.
# CPU times: user 122 ms, sys: 17.9 ms, total: 140 ms
# Wall time: 6min 1s

# %% [markdown]
# SageMaker FeatureStore adds metadata for each record that's ingested into the offline store.

# %%
#run time measurement. Can be removed
toc=time.time()
elapsed_time = toc-tic
print(elapsed_time)
str(timedelta(seconds=elapsed_time))
# Out:
# 400.03440022468567
# '0:06:40.034400'

# %% [markdown]
# ## Build Training Dataset
#
# SageMaker FeatureStore automatically builds the Glue Data Catalog for FeatureGroups (you can optionally turn it on/off while creating the FeatureGroup). In this example, we want to create one training dataset with FeatureValues from both identity and transaction FeatureGroups. This is done by utilizing the auto-built Catalog. We run an Athena query that joins the data stored in the offline store in S3 from the 2 FeatureGroups.

# %%
identity_query = identity_feature_group.athena_query()
transaction_query = transaction_feature_group.athena_query()

identity_table = identity_query.table_name
transaction_table = transaction_query.table_name

query_string = (
    'SELECT * FROM "'
    + transaction_table
    + '" LEFT JOIN "'
    + identity_table
    + '" ON "'
    + transaction_table
    + '".transactionid = "'
    + identity_table
    + '".transactionid'
)
print("Running " + query_string)

# run Athena query. The output is loaded to a Pandas dataframe.
# dataset = pd.DataFrame()
identity_query.run(
    query_string=query_string,
    output_location="s3://" + default_s3_bucket_name + "/" + prefix + "/query_results/",
)
identity_query.wait()
dataset = identity_query.as_dataframe()

dataset
# Out:
# Running SELECT * FROM "transaction-feature-group-01-19-37-17-1662061042" LEFT JOIN "identity-feature-group-01-19-37-17-1662061037" ON "transaction-feature-group-01-19-37-17-1662061042".transactionid = "identity-feature-group-01-19-37-17-1662061037".transactionid
#       transactionid  isfraud  transactiondt  transactionamt  card1  card2  \
# 0           3020760        0         842783           25.95  12839  321.0
# 1           3492253        0       13221857           38.97   9480  170.0
# 2           3499328        0       13399167          117.00   8965  245.0
# 3           3478813        0       12842634          117.00   9370  321.0
# 4           3201747        0        4997770           75.00   6951  111.0
# ...             ...      ...            ...             ...    ...    ...
# 1995        3075770        0        1873727           57.95  14392  526.0
# 1996        3577009        0       15800031          125.00   7207  111.0
# 1997        3384918        0       10021342           57.95  12544  321.0
# 1998        3184583        0        4470725           14.00   8320  476.0
# 1999        3495957        0       13325633           48.95   7919  194.0
#
#       card3       card4  card5   card6  ...  id_15  id_16  id_17  id_18  \
# 0     150.0        visa  226.0   debit  ...    NaN    NaN    NaN    NaN
# 1     150.0        visa  226.0   debit  ...    NaN    NaN    NaN    NaN
# 2     150.0        visa  226.0   debit  ...    NaN    NaN    NaN    NaN
# 3     150.0        visa  226.0  credit  ...    NaN    NaN    NaN    NaN
# 4     150.0        visa  226.0   debit  ...   99.0  124.0      T      F
# ...     ...         ...    ...     ...  ...    ...    ...    ...    ...
# 1995  150.0        visa  226.0   debit  ...    NaN    NaN    NaN    NaN
# 1996  150.0        visa  226.0   debit  ...  142.0  148.0      T      F
# 1997  150.0        visa  226.0   debit  ...    NaN    NaN    NaN    NaN
# 1998  150.0        visa  166.0   debit  ...  297.0  235.0      T      F
# 1999  150.0  mastercard  166.0   debit  ...    NaN    NaN    NaN    NaN
#
#       id_19  id_20   eventtime.1             write_time.1  \
# 0       NaN    NaN           NaN                      NaN
# 1       NaN    NaN           NaN                      NaN
# 2       NaN    NaN           NaN                      NaN
# 3       NaN    NaN           NaN                      NaN
# 4         F      F  1.662061e+09  2022-09-01 19:43:01.880
# ...     ...    ...           ...                      ...
# 1995    NaN    NaN           NaN                      NaN
# 1996      T      T  1.662061e+09  2022-09-01 19:43:02.307
# 1997    NaN    NaN           NaN                      NaN
# 1998      T      T  1.662061e+09  2022-09-01 19:43:02.307
# 1999    NaN    NaN           NaN                      NaN
#
#         api_invocation_time.1  is_deleted.1
# 0                         NaN           NaN
# 1                         NaN           NaN
# 2                         NaN           NaN
# 3                         NaN           NaN
# 4     2022-09-01 19:37:45.000         False
# ...                       ...           ...
# 1995                      NaN           NaN
# 1996  2022-09-01 19:37:46.000         False
# 1997                      NaN           NaN
# 1998  2022-09-01 19:37:45.000         False
# 1999                      NaN           NaN
#
# [2000 rows x 85 columns]

# %%
# Prepare query results for training.
query_execution = identity_query.get_query_execution()
query_result = (
    "s3://"
    + default_s3_bucket_name
    + "/"
    + prefix
    + "/query_results/"
    + query_execution["QueryExecution"]["QueryExecutionId"]
    + ".csv"
)
print(query_result)

# Select useful columns for training with target column as the first.
dataset = dataset[
    [
        "isfraud",
        "transactiondt",
        "transactionamt",
        "card1",
        "card2",
        "card3",
        "card5",
        "card_type_credit",
        "card_type_debit",
        "card_bank_american_express",
        "card_bank_discover",
        "card_bank_mastercard",
        "card_bank_visa",
        "id_01",
        "id_02",
        "id_03",
        "id_04",
        "id_05",
    ]
]

# Write to csv in S3 without headers and index column.
dataset.to_csv("dataset.csv", header=False, index=False)
s3_client.upload_file("dataset.csv", default_s3_bucket_name, prefix + "/training_input/dataset.csv")
dataset_uri_prefix = "s3://" + default_s3_bucket_name + "/" + prefix + "/training_input/"

dataset
# Out:
# s3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo/query_results/8b632fc2-848c-4af2-b5ec-4df44d09c292.csv
#       isfraud  transactiondt  transactionamt  card1  card2  card3  card5  \
# 0           0         842783           25.95  12839  321.0  150.0  226.0
# 1           0       13221857           38.97   9480  170.0  150.0  226.0
# 2           0       13399167          117.00   8965  245.0  150.0  226.0
# 3           0       12842634          117.00   9370  321.0  150.0  226.0
# 4           0        4997770           75.00   6951  111.0  150.0  226.0
# ...       ...            ...             ...    ...    ...    ...    ...
# 1995        0        1873727           57.95  14392  526.0  150.0  226.0
# 1996        0       15800031          125.00   7207  111.0  150.0  226.0
# 1997        0       10021342           57.95  12544  321.0  150.0  226.0
# 1998        0        4470725           14.00   8320  476.0  150.0  166.0
# 1999        0       13325633           48.95   7919  194.0  150.0  166.0
#
#       card_type_credit  card_type_debit  card_bank_american_express  \
# 0                    0                1                           0
# 1                    0                1                           0
# 2                    0                1                           0
# 3                    1                0                           0
# 4                    0                1                           0
# ...                ...              ...                         ...
# 1995                 0                1                           0
# 1996                 0                1                           0
# 1997                 0                1                           0
# 1998                 0                1                           0
# 1999                 0                1                           0
#
#       card_bank_discover  card_bank_mastercard  card_bank_visa  id_01  \
# 0                      0                     0               1    NaN
# 1                      0                     0               1    NaN
# 2                      0                     0               1    NaN
# 3                      0                     0               1    NaN
# 4                      0                     0               1   -5.0
# ...                  ...                   ...             ...    ...
# 1995                   0                     0               1    NaN
# 1996                   0                     0               1   -5.0
# 1997                   0                     0               1    NaN
# 1998                   0                     0               1    0.0
# 1999                   0                     1               0    NaN
#
#          id_02  id_03  id_04  id_05
# 0          NaN    NaN    NaN    NaN
# 1          NaN    NaN    NaN    NaN
# 2          NaN    NaN    NaN    NaN
# 3          NaN    NaN    NaN    NaN
# 4     302960.0    0.0    0.0    0.0
# ...        ...    ...    ...    ...
# 1995       NaN    NaN    NaN    NaN
# 1996  108350.0    0.0    0.0    1.0
# 1997       NaN    NaN    NaN    NaN
# 1998    2215.0    0.0    0.0   11.0
# 1999       NaN    NaN    NaN    NaN
#
# [2000 rows x 18 columns]

# %%
#run time measurement. Can be removed
toc=time.time()
elapsed_time = toc-tic
print(elapsed_time)
str(timedelta(seconds=elapsed_time))
# Out:
# 405.8861367702484
# '0:06:45.886137'

# %% [markdown]
# ## Train and Deploy the Model
#
# Now it's time to launch a Training job to fit our model. We use the gradient boosting algorithm provided by XGBoost libary to fit our data, call the SageMaker XGBoost container and construct a generic SageMaker estimator.
# To save time, we will skip the training step and use the model that has been previously trained on this dataset already. You can view the training steps in sagemaker_featurestore_fraud_detection_python_sdk_long.ipynb notebook.

# %% [markdown]
# ## Set up Hosting for the Model

# %%
import os
s3_model_path=feature_store_session.upload_data(path="model", bucket=default_s3_bucket_name, key_prefix=prefix + "/model")
model_artifacts=os.path.join(s3_model_path, "model.tar.gz")

# %%
from sagemaker import model

# retrieve xgboost docker container image from AWA ECR (Elastic Container Registry)
image_uri = sagemaker.image_uris.retrieve(
    framework="xgboost",
    region=region,
    version="1.0-1",
    py_version="py3"
)

print(image_uri)
print(model_artifacts)

#Initialize SageMaker model.
training_model = model.Model(
    image_uri=image_uri, 
    model_data=model_artifacts,
    role=role,
    sagemaker_session=feature_store_session,
#    vpc_config = vpc_confg,
#    enable_network_isolation = False,
#    model_kms_key=model_kms_key,
)
# Out:
# 246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3
# s3://datalab-feature-store-bucket-se/home/sermolin/featurestore/sagemaker-featurestore-demo/model/model.tar.gz

# %%
# %%time
#Deploy SageMaker model on an endpoint.
from time import gmtime, strftime
realtime_endpoint_name = "xgboost-ep-sdk-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
predictor=training_model.deploy(
    initial_instance_count = 1,
    instance_type='ml.c4.xlarge',
    endpoint_name=realtime_endpoint_name,
#    serializer,
#    deserializer,
#    kms_key=None,
#    wait=True,
    )
# Out:
# ------!CPU times: user 92 ms, sys: 4.83 ms, total: 96.8 ms
# Wall time: 3min 1s

# %%
#run time measurement. Can be removed
toc=time.time()
elapsed_time = toc-tic
print(elapsed_time)
str(timedelta(seconds=elapsed_time))
# Out:
# 587.3555340766907
# '0:09:47.355534'

# %% [markdown]
# ## SageMaker FeatureStore During Inference
#
# SageMaker FeatureStore can be useful in supplementing data for inference requests because of the low-latency GetRecord functionality. For this demo, we will be given a TransactionId and query our online FeatureGroups for data on the transaction to build our inference request.

# %%
# Incoming inference request.
transaction_id = str(3450774)

# Helper to parse the feature value from the record.
def get_feature_value(record, feature_name):
    return str(list(filter(lambda r: r["FeatureName"] == feature_name, record))[0]["ValueAsString"])


transaction_response = featurestore_runtime.get_record(
    FeatureGroupName=transaction_feature_group_name, RecordIdentifierValueAsString=transaction_id
)
transaction_record = transaction_response["Record"]

transaction_test_data = [
    get_feature_value(transaction_record, "TransactionDT"),
    get_feature_value(transaction_record, "TransactionAmt"),
    get_feature_value(transaction_record, "card1"),
    get_feature_value(transaction_record, "card2"),
    get_feature_value(transaction_record, "card3"),
    get_feature_value(transaction_record, "card5"),
    get_feature_value(transaction_record, "card_type_credit"),
    get_feature_value(transaction_record, "card_type_debit"),
    get_feature_value(transaction_record, "card_bank_american_express"),
    get_feature_value(transaction_record, "card_bank_discover"),
    get_feature_value(transaction_record, "card_bank_mastercard"),
    get_feature_value(transaction_record, "card_bank_visa"),
]

identity_response = featurestore_runtime.get_record(
    FeatureGroupName=identity_feature_group_name, RecordIdentifierValueAsString=transaction_id
)
identity_record = identity_response["Record"]
id_test_data = [
    get_feature_value(identity_record, "id_01"),
    get_feature_value(identity_record, "id_02"),
    get_feature_value(identity_record, "id_03"),
    get_feature_value(identity_record, "id_04"),
    get_feature_value(identity_record, "id_05"),
]

# Join all pieces for inference request.
inference_request = []
inference_request.extend(transaction_test_data[:])
inference_request.extend(id_test_data[:])

inference_request
# Out:
# ['11923451',
#  '50.0',
#  '12501',
#  '490.0',
#  '150.0',
#  '226.0',
#  '0',
#  '1',
#  '0',
#  '0',
#  '0',
#  '1',
#  '-40',
#  '20130.0',
#  '0.0',
#  '0.0',
#  '16.0']

# %%
import boto3
runtime = boto3.client(service_name="sagemaker-runtime")
realtime_response_sdk = runtime.invoke_endpoint(
    EndpointName=realtime_endpoint_name,
    Body=(",".join(inference_request)),
    ContentType="text/csv",
)

print("fraud probability of the transaction: ")
print(realtime_response_sdk["Body"].read())
# Out:
# fraud probability of the transaction:
# b'0.8026058077812195'

# %% [markdown]
# ## Cleanup Resources

# %%
training_model.delete_model()
feature_store_session.delete_endpoint(endpoint_name=realtime_endpoint_name)

# %%
identity_feature_group.delete()
transaction_feature_group.delete()

# %%
# restore original boto3 version
# %pip install 'boto3=={}'.format(original_boto3_version)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install 'boto3=={}'.format(original_boto3_version)'
# Note: you may need to restart the kernel to use updated packages.

# %%
#run time measurement. Can be removed
toc=time.time()
elapsed_time = toc-tic
print(elapsed_time)
str(timedelta(seconds=elapsed_time))
# Out:
# 596.4023768901825
# '0:09:56.402377'
