# %%
# %%sh
# pip install --upgrade pip
# pip install sagemaker awscli boto3 --upgrade
# Out:
# Requirement already up-to-date: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (20.0.2)
# Requirement already up-to-date: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.55.3)
# Requirement already up-to-date: awscli in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.18.39)
# Requirement already up-to-date: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.12.39)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.14.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.5.0)
# Requirement already satisfied, skipping upgrade: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.6.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.1)
# Requirement already satisfied, skipping upgrade: smdebug-rulesconfig==0.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.0)
# Requirement already satisfied, skipping upgrade: rsa<=3.5.0,>=3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (3.4.2)
# Requirement already satisfied, skipping upgrade: botocore==1.15.39 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (1.15.39)
# Requirement already satisfied, skipping upgrade: colorama<0.4.4,>=0.2.5; python_version != "3.4" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (0.3.9)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (0.3.3)
# Requirement already satisfied, skipping upgrade: PyYAML<5.4,>=3.10; python_version != "3.4" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (5.3.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awscli) (0.14)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3) (0.9.4)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.0.0)
# Requirement already satisfied, skipping upgrade: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf3-to-dict>=0.1.5->sagemaker) (1.11.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (39.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.2.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from rsa<=3.5.0,>=3.1.2->awscli) (0.4.8)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore==1.15.39->awscli) (2.7.3)
# Requirement already satisfied, skipping upgrade: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore==1.15.39->awscli) (1.23)

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %% [markdown]
# # Direct Marketing with Amazon SageMaker AutoPilot
#
# Last update: February 6th, 2019

# %%
import sagemaker
import smdebug_rulesconfig as rule_configs
import boto3
import os, sys

print (sagemaker.__version__)

sess   = sagemaker.Session()
bucket = sess.default_bucket()                     
prefix = 'sagemaker/DEMO-automl-dm'
region = boto3.Session().region_name
# Out:
# 1.55.3

# %%
import numpy as np 
import pandas as pd

# %%
# !wget -N --no-check-certificate https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# !unzip -o bank-additional.zip
# Out:
# --2020-04-11 22:08:30--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘bank-additional.zip’ not modified on server. Omitting download.
#
# Archive:  bank-additional.zip
#   inflating: bank-additional/.DS_Store
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %% [markdown]
# Let's read the CSV file into a Pandas data frame and take a look at the first few lines.

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pd.read_csv('./bank-additional/bank-additional-full.csv', sep=';')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page
data[:10] # Show the first 10 lines
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   may         mon       261         1    999         0
# 1  telephone   may         mon       149         1    999         0
# 2  telephone   may         mon       226         1    999         0
# 3  telephone   may         mon       151         1    999         0
# 4  telephone   may         mon       307         1    999         0
# 5  telephone   may         mon       198         1    999         0
# 6  telephone   may         mon       139         1    999         0
# 7  telephone   may         mon       217         1    999         0
# 8  telephone   may         mon       380         1    999         0
# 9  telephone   may         mon        50         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
# 5  nonexistent           1.1          93.994          -36.4      4.857
# 6  nonexistent           1.1          93.994          -36.4      4.857
# 7  nonexistent           1.1          93.994          -36.4      4.857
# 8  nonexistent           1.1          93.994          -36.4      4.857
# 9  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed   y
# 0       5191.0  no
# 1       5191.0  no
# 2       5191.0  no
# 3       5191.0  no
# 4       5191.0  no
# 5       5191.0  no
# 6       5191.0  no
# 7       5191.0  no
# 8       5191.0  no
# 9       5191.0  no

# %%
data.shape # (number of lines, number of columns)
# Out:
# (41188, 21)

# %% [markdown]
# ## Splitting the dataset
#
# We split the dataset into training (95%) and test (5%) datasets. We will use the training dataset for AutoML, where it will be automatically split again for training and validation.
#
# Once the model has been deployed, we'll use the test dataset to evaluate its performance.

# %%
# Set the seed to 123 for reproductibility
# https://pandas.pydata.org/pandas-docs/version/0.25/generated/pandas.DataFrame.sample.html
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.split.html
train_data, test_data, _ = np.split(data.sample(frac=1, random_state=123), 
                                                  [int(0.95 * len(data)), int(len(data))])  

# Save to CSV files
train_data.to_csv('automl-train.csv', index=False, header=True, sep=',') # Need to keep column names
test_data.to_csv('automl-test.csv', index=False, header=True, sep=',')

# %%
# !ls -l automl*.csv
# Out:
# -rw-rw-r-- 1 ec2-user ec2-user  257339 Apr 11 22:08 automl-test.csv
# -rw-rw-r-- 1 ec2-user ec2-user 4889516 Apr 11 22:08 automl-train.csv

# %% [markdown]
# **No preprocessing needed!** AutoML will take care of this, so let's just copy the training set to S3.

# %%
s3_input_data = sess.upload_data(path="automl-train.csv", key_prefix=prefix + "/input")
print(s3_input_data)
# Out:
# s3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/input/automl-train.csv

# %% [markdown]
# ## Setting up the SageMaker AutoPilot job
#
# After uploading the dataset to S3, we can invoke SageMaker AutoPilot to find the best ML pipeline to train a model on this dataset.
#
# The required inputs for invoking a SageMaker AutoML job are the dataset location in S3, the name of the column of the dataset you want to predict (`y` in this case) and an IAM role.

# %%
from sagemaker.automl.automl import AutoML
# https://sagemaker.readthedocs.io/en/stable/automl.html

role = sagemaker.get_execution_role()
job_tags =[{ 
         "Key": "xgb-c1-automl",
         "Value": "job1"
      }]
auto_ml_job = AutoML(
    role = role,                                              # IAM permissions for SageMaker
    sagemaker_session = sess,                                 # 
    target_attribute_name = 'y',                              # The column we want to predict
    output_path = 's3://{}/{}/output'.format(bucket,prefix),  # Save artefacts here
    max_candidates = 100,                                     # Default is 500 
    base_job_name = 'xgb-c1',                                 # search convinience
    tags = job_tags,
    max_runtime_per_training_job_in_seconds = 600, 
    total_job_runtime_in_seconds = 3600
)

# %% [markdown]
# ## Launching the SageMaker AutoPilot job
#
# We can now launch the job by calling the `fit()` API.

# %%
auto_ml_job.fit(inputs=s3_input_data, logs=False, wait=False)

# %%
auto_ml_job.describe_auto_ml_job()
# Out:
# {'AutoMLJobName': 'xgb-c1-2020-04-11-22-09-21-981',
#  'AutoMLJobArn': 'arn:aws:sagemaker:us-west-1:262002448484:automl-job/xgb-c1-2020-04-11-22-09-21-981',
#  'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/input/automl-train.csv'}},
#    'TargetAttributeName': 'y'}],
#  'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/output'},
#  'RoleArn': 'arn:aws:iam::262002448484:role/service-role/AmazonSageMaker-ExecutionRole-20190606T095855',
#  'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 100,
#    'MaxRuntimePerTrainingJobInSeconds': 600,
#    'MaxAutoMLJobRuntimeInSeconds': 3600},
#   'SecurityConfig': {'EnableInterContainerTrafficEncryption': False}},
#  'CreationTime': datetime.datetime(2020, 4, 11, 22, 9, 22, 132000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2020, 4, 11, 22, 9, 23, 241000, tzinfo=tzlocal()),
#  'AutoMLJobStatus': 'InProgress',
#  'AutoMLJobSecondaryStatus': 'AnalyzingData',
#  'GenerateCandidateDefinitionsOnly': False,
#  'ResponseMetadata': {'RequestId': '8fccdf80-81a0-4717-b614-0bba4bb1672a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8fccdf80-81a0-4717-b614-0bba4bb1672a',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '947',
#    'date': 'Sat, 11 Apr 2020 22:09:22 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Tracking the progress of the AutoPilot job
# SageMaker AutoPilot job consists of four high-level steps :
# * Data Preprocessing, where the dataset is split into train and validation sets.
# * Recommending Pipelines, where the dataset is analyzed and SageMaker AutoPilot comes up with a list of ML pipelines that should be tried out on the dataset.
# * Automatic Feature Engineering, where SageMaker AutoPilot performs feature transformation on individual features of the dataset as well as at an aggregate level.
# * ML pipeline selection and hyperparameter tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline).

# %%
from time import sleep

job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('AnalyzingData'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Data analysis complete")
# Out:
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress FeatureEngineering
# Data analysis complete

# %% [markdown]
# ## Viewing notebooks generated by SageMaker AutoPilot
# Once data analysis is complete, SageMaker AutoPilot generates two notebooks:
# * Data exploration,
# * Candidate definition.

# %%
job = auto_ml_job.describe_auto_ml_job()
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']

print(job_candidate_notebook)
print(job_data_notebook)
# Out:
# s3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/output/xgb-c1-2020-04-11-22-09-21-981/sagemaker-automl-candidates/pr-1-4b34747772154bc0b1d5924ce17aa391a9917a53f2084af6b9542512b9/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# s3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/output/xgb-c1-2020-04-11-22-09-21-981/sagemaker-automl-candidates/pr-1-4b34747772154bc0b1d5924ce17aa391a9917a53f2084af6b9542512b9/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# Let's copy these two notebooks.

# %%
# %%sh -s $job_candidate_notebook $job_data_notebook
# aws s3 cp $1 .
# aws s3 cp $2 .
# Out:
# download: s3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/output/xgb-c1-2020-04-11-22-09-21-981/sagemaker-automl-candidates/pr-1-4b34747772154bc0b1d5924ce17aa391a9917a53f2084af6b9542512b9/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to ./SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-us-west-1-262002448484/sagemaker/DEMO-automl-dm/output/xgb-c1-2020-04-11-22-09-21-981/sagemaker-automl-candidates/pr-1-4b34747772154bc0b1d5924ce17aa391a9917a53f2084af6b9542512b9/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to ./SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# Go back to the folder view, and open these notebooks. Lots of useful information in there!

# %% [markdown]
# SageMaker AutoPilot then launches feature engineering, and prepares different training and validation datasets.

# %%
job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('FeatureEngineering'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Feature engineering complete")
# Out:
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress ModelTuning
# Feature engineering complete

# %% [markdown]
# Once feature engineering is complete, SageMaker AutoPilot launches Automatic Model Tuning on the different candidates. While model tuning is running, we can explore its progress with SageMaker Experiments.

# %%
import pandas as pd
from sagemaker.analytics import ExperimentAnalytics, TrainingJobAnalytics

exp = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=job['AutoMLJobName'] + '-aws-auto-ml-job',
)

df = exp.dataframe()
print("Number of jobs: ", len(df))

# Move metric to first column
df = pd.concat([df['ObjectiveMetric - Max'], df.drop(['ObjectiveMetric - Max'], axis=1)], axis=1)
# Show top 5 jobs
df.sort_values('ObjectiveMetric - Max', ascending=0)[:5]
# Out:
# Number of jobs:  121
#     ObjectiveMetric - Max                                 TrialComponentName  \
# 44               0.917827  tuning-job-1-b8e76c119ad1486ebf-056-9a194682-a...
# 47               0.917827  tuning-job-1-b8e76c119ad1486ebf-053-77caf8d2-a...
# 71               0.917572  tuning-job-1-b8e76c119ad1486ebf-029-b0b9294f-a...
# 35               0.917444  tuning-job-1-b8e76c119ad1486ebf-065-53a4cfb9-a...
# 37               0.917188  tuning-job-1-b8e76c119ad1486ebf-062-6acfde2b-a...
#
#                                           DisplayName  \
# 44  tuning-job-1-b8e76c119ad1486ebf-056-9a194682-a...
# 47  tuning-job-1-b8e76c119ad1486ebf-053-77caf8d2-a...
# 71  tuning-job-1-b8e76c119ad1486ebf-029-b0b9294f-a...
# 35  tuning-job-1-b8e76c119ad1486ebf-065-53a4cfb9-a...
# 37  tuning-job-1-b8e76c119ad1486ebf-062-6acfde2b-a...
#
#                                             SourceArn  \
# 44  arn:aws:sagemaker:us-west-1:262002448484:train...
# 47  arn:aws:sagemaker:us-west-1:262002448484:train...
# 71  arn:aws:sagemaker:us-west-1:262002448484:train...
# 35  arn:aws:sagemaker:us-west-1:262002448484:train...
# 37  arn:aws:sagemaker:us-west-1:262002448484:train...
#
#                                    SageMaker.ImageUri  \
# 44  746614075791.dkr.ecr.us-west-1.amazonaws.com/s...
# 47  746614075791.dkr.ecr.us-west-1.amazonaws.com/s...
# 71  746614075791.dkr.ecr.us-west-1.amazonaws.com/s...
# 35  746614075791.dkr.ecr.us-west-1.amazonaws.com/s...
# 37  746614075791.dkr.ecr.us-west-1.amazonaws.com/s...
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 44                      1.0          ml.m5.4xlarge                      50.0
# 47                      1.0          ml.m5.4xlarge                      50.0
# 71                      1.0          ml.m5.4xlarge                      50.0
# 35                      1.0          ml.m5.4xlarge                      50.0
# 37                      1.0          ml.m5.4xlarge                      50.0
#
#    _tuning_objective_metric     alpha  colsample_bytree       eta      gamma  \
# 44      validation:accuracy  0.000238          0.903418  0.651562  24.086601
# 47      validation:accuracy  0.059646          0.973912  0.297536   0.000137
# 71      validation:accuracy  0.000074          0.801532  0.221304   0.000005
# 35      validation:accuracy  0.000026          0.775335  0.031880   0.000105
# 37      validation:accuracy  0.007904          0.642642  0.039466   8.863009
#
#       lambda  max_depth  min_child_weight  num_round     objective  subsample  \
# 44  0.003371        5.0          0.000755      426.0  binary:hinge   0.901838
# 47  0.029299        7.0          0.000016      121.0  binary:hinge   0.967283
# 71  0.016209        8.0          0.000164       56.0  binary:hinge   0.909361
# 35  0.000002        9.0          2.492775      512.0  binary:hinge   0.579126
# 37  0.000002        6.0          0.000047      459.0  binary:hinge   0.935931
#
#     ObjectiveMetric - Min  ObjectiveMetric - Avg  ObjectiveMetric - StdDev  \
# 44               0.835527               0.913341                  0.015488
# 47               0.112588               0.891336                  0.132410
# 71               0.112588               0.816568                  0.265369
# 35               0.112588               0.723321                  0.330635
# 37               0.112588               0.749656                  0.315982
#
#     ObjectiveMetric - Last  ObjectiveMetric - Count  validation:error - Min  \
# 44                0.917444                     28.0                0.082173
# 47                0.915655                     37.0                0.082173
# 71                0.917061                     17.0                0.082428
# 35                0.916933                     70.0                0.082556
# 37                0.917061                     67.0                0.082812
#
#     validation:error - Max  validation:error - Avg  validation:error - StdDev  \
# 44                0.164473                0.086659                   0.015488
# 47                0.887412                0.108664                   0.132410
# 71                0.887412                0.183432                   0.265369
# 35                0.887412                0.276679                   0.330635
# 37                0.887412                0.250344                   0.315982
#
#     validation:error - Last  validation:error - Count  \
# 44                 0.082556                      28.0
# 47                 0.084345                      37.0
# 71                 0.082939                      17.0
# 35                 0.083067                      70.0
# 37                 0.082939                      67.0
#
#     validation:accuracy - Min  validation:accuracy - Max  \
# 44                   0.835527                   0.917827
# 47                   0.112588                   0.917827
# 71                   0.112588                   0.917572
# 35                   0.112588                   0.917444
# 37                   0.112588                   0.917188
#
#     validation:accuracy - Avg  validation:accuracy - StdDev  \
# 44                   0.913341                      0.015488
# 47                   0.891336                      0.132410
# 71                   0.816568                      0.265369
# 35                   0.723321                      0.330635
# 37                   0.749656                      0.315982
#
#     validation:accuracy - Last  validation:accuracy - Count  \
# 44                    0.917444                         28.0
# 47                    0.915655                         37.0
# 71                    0.917061                         17.0
# 35                    0.916933                         70.0
# 37                    0.917061                         67.0
#
#     train:error - Min  train:error - Max  train:error - Avg  \
# 44           0.080344           0.163722           0.084894
# 47           0.056480           0.887519           0.090502
# 71           0.059323           0.887519           0.167646
# 35           0.062965           0.887519           0.263995
# 37           0.079130           0.887519           0.248652
#
#     train:error - StdDev  train:error - Last  train:error - Count  \
# 44              0.015710            0.080408                 28.0
# 47              0.136047            0.056480                 37.0
# 71              0.271588            0.059323                 17.0
# 35              0.337850            0.062965                 70.0
# 37              0.316900            0.079194                 67.0
#
#     train:accuracy - Min  train:accuracy - Max  train:accuracy - Avg  \
# 44              0.836278              0.919656              0.915106
# 47              0.112481              0.943520              0.909498
# 71              0.112481              0.940677              0.832354
# 35              0.112481              0.937035              0.736005
# 37              0.112481              0.920870              0.751348
#
#     train:accuracy - StdDev  train:accuracy - Last  train:accuracy - Count  \
# 44                 0.015710               0.919592                    28.0
# 47                 0.136047               0.943520                    37.0
# 71                 0.271588               0.940677                    17.0
# 35                 0.337850               0.937035                    70.0
# 37                 0.316900               0.920806                    67.0
#
#    binary_classifier_model_selection_criteria  l1  learning_rate loss  \
# 44                                        NaN NaN            NaN  NaN
# 47                                        NaN NaN            NaN  NaN
# 71                                        NaN NaN            NaN  NaN
# 35                                        NaN NaN            NaN  NaN
# 37                                        NaN NaN            NaN  NaN
#
#     mini_batch_size  num_models positive_example_weight_mult predictor_type  \
# 44              NaN         NaN                          NaN            NaN
# 47              NaN         NaN                          NaN            NaN
# 71              NaN         NaN                          NaN            NaN
# 35              NaN         NaN                          NaN            NaN
# 37              NaN         NaN                          NaN            NaN
#
#     wd  validation:objective_loss - Min  validation:objective_loss - Max  \
# 44 NaN                              NaN                              NaN
# 47 NaN                              NaN                              NaN
# 71 NaN                              NaN                              NaN
# 35 NaN                              NaN                              NaN
# 37 NaN                              NaN                              NaN
#
#     validation:objective_loss - Avg  validation:objective_loss - StdDev  \
# 44                              NaN                                 NaN
# 47                              NaN                                 NaN
# 71                              NaN                                 NaN
# 35                              NaN                                 NaN
# 37                              NaN                                 NaN
#
#     validation:objective_loss - Last  validation:objective_loss - Count  \
# 44                               NaN                                NaN
# 47                               NaN                                NaN
# 71                               NaN                                NaN
# 35                               NaN                                NaN
# 37                               NaN                                NaN
#
#     train:progress - Min  train:progress - Max  train:progress - Avg  \
# 44                   NaN                   NaN                   NaN
# 47                   NaN                   NaN                   NaN
# 71                   NaN                   NaN                   NaN
# 35                   NaN                   NaN                   NaN
# 37                   NaN                   NaN                   NaN
#
#     train:progress - StdDev  train:progress - Last  train:progress - Count  \
# 44                      NaN                    NaN                     NaN
# 47                      NaN                    NaN                     NaN
# 71                      NaN                    NaN                     NaN
# 35                      NaN                    NaN                     NaN
# 37                      NaN                    NaN                     NaN
#
#     validation:recall - Min  validation:recall - Max  validation:recall - Avg  \
# 44                      NaN                      NaN                      NaN
# 47                      NaN                      NaN                      NaN
# 71                      NaN                      NaN                      NaN
# 35                      NaN                      NaN                      NaN
# 37                      NaN                      NaN                      NaN
#
#     validation:recall - StdDev  validation:recall - Last  \
# 44                         NaN                       NaN
# 47                         NaN                       NaN
# 71                         NaN                       NaN
# 35                         NaN                       NaN
# 37                         NaN                       NaN
#
#     validation:recall - Count  \
# 44                        NaN
# 47                        NaN
# 71                        NaN
# 35                        NaN
# 37                        NaN
#
#     validation:binary_classification_accuracy - Min  \
# 44                                              NaN
# 47                                              NaN
# 71                                              NaN
# 35                                              NaN
# 37                                              NaN
#
#     validation:binary_classification_accuracy - Max  \
# 44                                              NaN
# 47                                              NaN
# 71                                              NaN
# 35                                              NaN
# 37                                              NaN
#
#     validation:binary_classification_accuracy - Avg  \
# 44                                              NaN
# 47                                              NaN
# 71                                              NaN
# 35                                              NaN
# 37                                              NaN
#
#     validation:binary_classification_accuracy - StdDev  \
# 44                                                NaN
# 47                                                NaN
# 71                                                NaN
# 35                                                NaN
# 37                                                NaN
#
#     validation:binary_classification_accuracy - Last  \
# 44                                               NaN
# 47                                               NaN
# 71                                               NaN
# 35                                               NaN
# 37                                               NaN
#
#     validation:binary_classification_accuracy - Count  train:throughput - Min  \
# 44                                                NaN                     NaN
# 47                                                NaN                     NaN
# 71                                                NaN                     NaN
# 35                                                NaN                     NaN
# 37                                                NaN                     NaN
#
#     train:throughput - Max  train:throughput - Avg  train:throughput - StdDev  \
# 44                     NaN                     NaN                        NaN
# 47                     NaN                     NaN                        NaN
# 71                     NaN                     NaN                        NaN
# 35                     NaN                     NaN                        NaN
# 37                     NaN                     NaN                        NaN
#
#     train:throughput - Last  train:throughput - Count  \
# 44                      NaN                       NaN
# 47                      NaN                       NaN
# 71                      NaN                       NaN
# 35                      NaN                       NaN
# 37                      NaN                       NaN
#
#     train:objective_loss - Min  train:objective_loss - Max  \
# 44                         NaN                         NaN
# 47                         NaN                         NaN
# 71                         NaN                         NaN
# 35                         NaN                         NaN
# 37                         NaN                         NaN
#
#     train:objective_loss - Avg  train:objective_loss - StdDev  \
# 44                         NaN                            NaN
# 47                         NaN                            NaN
# 71                         NaN                            NaN
# 35                         NaN                            NaN
# 37                         NaN                            NaN
#
#     train:objective_loss - Last  train:objective_loss - Count  \
# 44                          NaN                           NaN
# 47                          NaN                           NaN
# 71                          NaN                           NaN
# 35                          NaN                           NaN
# 37                          NaN                           NaN
#
#     validation:objective_loss:final - Min  \
# 44                                    NaN
# 47                                    NaN
# 71                                    NaN
# 35                                    NaN
# 37                                    NaN
#
#     validation:objective_loss:final - Max  \
# 44                                    NaN
# 47                                    NaN
# 71                                    NaN
# 35                                    NaN
# 37                                    NaN
#
#     validation:objective_loss:final - Avg  \
# 44                                    NaN
# 47                                    NaN
# 71                                    NaN
# 35                                    NaN
# 37                                    NaN
#
#     validation:objective_loss:final - StdDev  \
# 44                                       NaN
# 47                                       NaN
# 71                                       NaN
# 35                                       NaN
# 37                                       NaN
#
#     validation:objective_loss:final - Last  \
# 44                                     NaN
# 47                                     NaN
# 71                                     NaN
# 35                                     NaN
# 37                                     NaN
#
#     validation:objective_loss:final - Count  validation:binary_f_beta - Min  \
# 44                                      NaN                             NaN
# 47                                      NaN                             NaN
# 71                                      NaN                             NaN
# 35                                      NaN                             NaN
# 37                                      NaN                             NaN
#
#     validation:binary_f_beta - Max  validation:binary_f_beta - Avg  \
# 44                             NaN                             NaN
# 47                             NaN                             NaN
# 71                             NaN                             NaN
# 35                             NaN                             NaN
# 37                             NaN                             NaN
#
#     validation:binary_f_beta - StdDev  validation:binary_f_beta - Last  \
# 44                                NaN                              NaN
# 47                                NaN                              NaN
# 71                                NaN                              NaN
# 35                                NaN                              NaN
# 37                                NaN                              NaN
#
#     validation:binary_f_beta - Count  validation:precision - Min  \
# 44                               NaN                         NaN
# 47                               NaN                         NaN
# 71                               NaN                         NaN
# 35                               NaN                         NaN
# 37                               NaN                         NaN
#
#     validation:precision - Max  validation:precision - Avg  \
# 44                         NaN                         NaN
# 47                         NaN                         NaN
# 71                         NaN                         NaN
# 35                         NaN                         NaN
# 37                         NaN                         NaN
#
#     validation:precision - StdDev  validation:precision - Last  \
# 44                            NaN                          NaN
# 47                            NaN                          NaN
# 71                            NaN                          NaN
# 35                            NaN                          NaN
# 37                            NaN                          NaN
#
#     validation:precision - Count SageMaker.ModelName  \
# 44                           NaN                 NaN
# 47                           NaN                 NaN
# 71                           NaN                 NaN
# 35                           NaN                 NaN
# 37                           NaN                 NaN
#
#    SageMaker.ModelPrimary.DataUrl SageMaker.ModelPrimary.Image  \
# 44                            NaN                          NaN
# 47                            NaN                          NaN
# 71                            NaN                          NaN
# 35                            NaN                          NaN
# 37                            NaN                          NaN
#
#    processor_module sagemaker_program sagemaker_submit_directory  \
# 44              NaN               NaN                        NaN
# 47              NaN               NaN                        NaN
# 71              NaN               NaN                        NaN
# 35              NaN               NaN                        NaN
# 37              NaN               NaN                        NaN
#
#    input_channel_mode job_name label_col
# 44                NaN      NaN       NaN
# 47                NaN      NaN       NaN
# 71                NaN      NaN       NaN
# 35                NaN      NaN       NaN
# 37                NaN      NaN       NaN

# %%
job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('ModelTuning'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Model tuning complete")
# Out:
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# Completed MaxCandidatesReached
# Model tuning complete

# %% [markdown]
# ## Deploying the best candidate
# Now that we have successfully completed the AutoML job on our dataset and visualized the trials, we can create a model from any of the trials with a single API call and then deploy that model for online or batch prediction using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html). For this notebook, we deploy only the best performing trial for inference.

# %% [markdown]
# The best candidate is the one we're really interested in.

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())

best_cand=auto_ml_job.best_candidate()

print("Best Candidate: {}".format(best_cand['CandidateName']))
print("Metric: {} - {:0.3f}".format(best_cand['FinalAutoMLJobObjectiveMetric']['MetricName'], \
                                    best_cand['FinalAutoMLJobObjectiveMetric']['Value']))

endpoint_name = job['AutoMLJobName']+'-'+timestamp
# Out:
# Best Candidate: tuning-job-1-b8e76c119ad1486ebf-078-bfb734b6
# Metric: validation:accuracy - 0.919

# %%
#if no candidate is specified, the best candidate is deployed by default
auto_ml_job.deploy(
    initial_instance_count = 1,
    instance_type = 'ml.m4.xlarge',
    endpoint_name = endpoint_name
)
# Out:
# ---------------!

# %% [markdown]
# ## Scoring the best candidate

# %% [markdown]
# Let's predict and score the validation set. We'll compute metrics ourselves just for fun.

# %%
from sagemaker.predictor import csv_serializer, RealTimePredictor
from sagemaker.content_types import CONTENT_TYPE_CSV

predictor = RealTimePredictor(
    endpoint=endpoint_name, 
    sagemaker_session=sess, 
    serializer=csv_serializer,
    content_type=CONTENT_TYPE_CSV, 
    accept='text/csv'
)

# %%
tp = tn = fp = fn = count = 0

with open('automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   # Skip header
        l = l.split(',')  # Split CSV line into feature array
        label = l[-1]     # Store 'yes'/'no' label
        l = l[:-1]        # Remove label
        l = ','.join(l)   # Rebuild CSV line without label
                
        response = predictor.predict(l)
        response = response.decode("utf-8")
        #print ("label %s response %s" %(label,response))

        if 'yes' in label:
            # Sample is positive
            if 'yes' in response:
                # True positive
                tp=tp+1
            else:
                # False negative
                fn=fn+1
        else:
            # Sample is negative
            if 'no' in response:
                # True negative
                tn=tn+1
            else:
                # False positive
                fp=fp+1
        count = count+1
        if (count % 100 == 0):   
            sys.stdout.write(str(count)+' ')
            
print ("Done")
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 Done

# %%
#Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall    = tn/(tn+fn)
f1        = (2*precision*recall)/(precision+recall)

print ("%.4f %.4f %.4f %.4f" % (accuracy, precision, recall, f1))
# Out:
# 1757 65
# 107 131
# 0.9165 0.6684 0.9426 0.7821

# %% [markdown]
# ## Deleting the endpoint
# Once that we're done predicting, we can delete the endpoint (and stop paying for it).

# %%
# Uncomment to delete
sess.delete_endpoint(predictor.endpoint)

# %% [markdown]
# The SageMaker AutoML job creates many underlying artifacts such as dataset splits, preprocessing scripts, preprocessed data, etc. Let's delete them.

# %%
import boto3

job_outputs_prefix = '{}/output/{}'.format(prefix, job['AutoMLJobName'])
print(job_outputs_prefix)

s3_bucket =boto3.resource('s3').Bucket(bucket)
# Uncomment to delete
s3_bucket.objects.filter(Prefix=job_outputs_prefix).delete()
# Out:
# sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848
# [{'ResponseMetadata': {'RequestId': '3219CD06C5C2DE40',
#    'HostId': 'ruA4IveVGknD269VWkT3TOFjhLsp5BJaJiBfV68w9Oq2EKFdW435AKugUNUEE5w3zBX5uZ1IT/w=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'ruA4IveVGknD269VWkT3TOFjhLsp5BJaJiBfV68w9Oq2EKFdW435AKugUNUEE5w3zBX5uZ1IT/w=',
#     'x-amz-request-id': '3219CD06C5C2DE40',
#     'date': 'Fri, 10 Apr 2020 04:17:37 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/generated_module/candidate_data_processors/dpp0.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_35.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_56.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_47.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_54.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_66.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/generated_module/candidate_data_processors/dpp7.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_99.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/validation/chunk_17.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_57.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_49.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/validation/chunk_12.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_72.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_78.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_53.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_55.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_52.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/data-processor-models/automl-202-dpp1-1-defc5db2851f4a4db92e3a47d0ea562b389ec8d6550d4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_33.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_44.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/validation/chunk_7.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_85.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/data-processor-models/automl-202-dpp3-1-bf08cdae390845ee823c153579f5adf0a875e0f7eeb44/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_90.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_31.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_58.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/generated_module/candidate_data_processors/dpp1.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_62.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/generated_module/candidate_data_processors/sagemaker_serve.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_84.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_59.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_39.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/sagemaker-automl-candidates/pr-1-030b25e8d7c140568ea07f050fb8ca0483d6001b836344c2bac9f612e0/generated_module/setup.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/data-processor-models/automl-202-dpp4-1-a508a3c3febd42718dd2dcc02a8a22e71bb8e000d8bc4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_46.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_80.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_68.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_95.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_22.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp4/rpb/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_26.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_27.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp3/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_69.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp5/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/validation/chunk_4.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/data-processor-models/automl-202-dpp7-1-272c35a5021d421e818fdeb665515bb81ecab163534a4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp2/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp1/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/preprocessed-data/tuning_data/train/chunk_36.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp7/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp0/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp6/csv/validation/chunk_17.csv.out'},
# ...
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp5-xgb/tuning-job-1-057e6ab534534d20be-008-c885ca9d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-085-3768d329/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-088-a5d4c8d1/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-055-8e09ca0f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-028-d9e5eaee/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-087-f7abb0dc/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-043-21fc289f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp8-xgb/tuning-job-1-057e6ab534534d20be-050-0f7bd0c4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-047-25bc669a/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp2-ll/tuning-job-1-057e6ab534534d20be-081-f51d69de/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-077-0d71cf57/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-071-069eb257/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp2-ll/tuning-job-1-057e6ab534534d20be-001-3be73e43/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-089-52ee9677/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp2-ll/tuning-job-1-057e6ab534534d20be-022-17ac7428/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp6-xgb/tuning-job-1-057e6ab534534d20be-019-02b26076/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp0-xgb/tuning-job-1-057e6ab534534d20be-036-47dd71f1/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-024-65610c36/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-030-9ec2e3f5/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-072-cf30e5b2/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-100-2dac00ff/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-056-f57eb5a3/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp7-xgb/tuning-job-1-057e6ab534534d20be-013-9c00fd0f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-060-705f51c8/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-079-b98a3825/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-091-33899790/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp7-xgb/tuning-job-1-057e6ab534534d20be-005-3bcd8f8d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-054-d5236a57/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp7-xgb/tuning-job-1-057e6ab534534d20be-011-cbd17641/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp0-xgb/tuning-job-1-057e6ab534534d20be-035-a4866ec0/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-069-f2ab2cc8/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-066-516ae0c4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp8-xgb/tuning-job-1-057e6ab534534d20be-038-46293996/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-044-a7b61f72/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-021-ce8427a7/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-093-bf202839/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-090-4bca3760/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp8/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp4-xgb/tuning-job-1-057e6ab534534d20be-016-cb482895/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-049-d8255cfb/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp2-ll/tuning-job-1-057e6ab534534d20be-033-e12d1fd5/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp0-xgb/tuning-job-1-057e6ab534534d20be-068-5e42d89d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-051-128d8fa3/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-053-4a6555b1/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-086-bbcd9cf5/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp0-xgb/tuning-job-1-057e6ab534534d20be-040-601a7d92/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-031-f991e9da/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp6-xgb/tuning-job-1-057e6ab534534d20be-007-5fd9250f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-082-976f3a31/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-092-b5dedef7/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/transformed-data/dpp9/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp1-xgb/tuning-job-1-057e6ab534534d20be-059-a74e7bcb/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-04-10-00-36-07-848/tuning/automl-202-dpp5-xgb/tuning-job-1-057e6ab534534d20be-003-bfdc897e/output/model.tar.gz'}]}]
